# %% [markdown]
# # Rabia Ibtasar- CS424

# %%
utility <- read.table(file = "https://www.evl.uic.edu/aej/424/utilitydata2020.tsv", sep = "\t", header = TRUE)

# %%
complete.cases(utility)
# Out:
#   [1] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#  [16] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#  [31] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#  [46] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#  [61] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#  [76] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#  [91] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
# [106] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
# [121] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
# [136] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
# [151] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
# [166] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
# ...

# %%
library(lubridate)
# Out:
# Attaching package: 'lubridate'
#
# The following object is masked from 'package:base':
#
#     date

# %%
utility
# Out:
#     Year Month Temp_F E_kWh_per_Day E_Cost Gas_Th_per_Day Gas_Cost
# 1   1998  8    70     22.4           77    0.5             15
# 2   1998  9    70     22.4           77    0.5             15
# 3   1998 10    53      8.6           33    2.2             35
# 4   1998 11    44      7.6           33    3.7             50
# 5   1998 12    35     10.0           39    5.9             82
# 6   1999  1    22     11.6           45    8.2             93
# 7   1999  2    34      8.4           32    5.8             64
# 8   1999  3    35      8.1           31    4.9             61
# 9   1999  4    47      7.3           29    2.8             38
# 10  1999  5    59     10.9           38    1.6             30
# 11  1999  6    71     15.9           60    0.7             18
# 12  1999  7    78     40.9          128    0.7             18
# 13  1999  8    72     32.5          100    0.8             20
# 14  1999  9    66     26.7           92    0.8             20
# ...

# %%
paste(utility$Year, utility$Month, "01", sep="-")
# Out:
#   [1] "1998-8-01"  "1998-9-01"  "1998-10-01" "1998-11-01" "1998-12-01"
#   [6] "1999-1-01"  "1999-2-01"  "1999-3-01"  "1999-4-01"  "1999-5-01"
#  [11] "1999-6-01"  "1999-7-01"  "1999-8-01"  "1999-9-01"  "1999-10-01"
#  [16] "1999-11-01" "1999-12-01" "2000-1-01"  "2000-2-01"  "2000-3-01"
#  [21] "2000-4-01"  "2000-5-01"  "2000-6-01"  "2000-7-01"  "2000-8-01"
#  [26] "2000-9-01"  "2000-10-01" "2000-11-01" "2000-12-01" "2001-1-01"
#  [31] "2001-2-01"  "2001-3-01"  "2001-4-01"  "2001-5-01"  "2001-6-01"
#  [36] "2001-7-01"  "2001-8-01"  "2001-9-01"  "2001-10-01" "2001-11-01"
#  [41] "2001-12-01" "2002-1-01"  "2002-2-01"  "2002-3-01"  "2002-4-01"
#  [46] "2002-5-01"  "2002-6-01"  "2002-7-01"  "2002-8-01"  "2002-9-01"
#  [51] "2002-10-01" "2002-11-01" "2002-12-01" "2003-1-01"  "2003-2-01"
#  [56] "2003-3-01"  "2003-4-01"  "2003-5-01"  "2003-6-01"  "2003-7-01"
#  [61] "2003-8-01"  "2003-9-01"  "2003-10-01" "2003-11-01" "2003-12-01"
# ...

# %%
utility$newDate <- ymd(paste(utility$Year, utility$Month, "01", sep="-"))

# %%
library(ggplot2)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang

# %%
ggplot(utility, aes(x=newDate, y=Temp_F)) + geom_point(color="blue") + geom_line()
# Out:
# plot without title

# %%
utility

# %%
ggplot(utility, aes(x=newDate, y=Gas_Th_per_Day)) + geom_point(color="blue") + geom_line()
# Out:
# plot without title

# %%
ggplot(utility, aes(x=newDate, y=10*Gas_Th_per_Day)) + geom_line(colour="#4488FF") + geom_line(aes(y=Temp_F, colour="#FFFFFF"))
# Out:
# plot without title

# %%
ggplot(utility, aes(x=newDate, y=E_kWh_per_Day)) + geom_point(color="blue") + geom_line() + coord_cartesian(ylim = c(0,60))

# %% [markdown]
# # Here I think I have found where the Natural gas usage declines greatly around 2010. This could be where they replaced the furnace.

# %%
junes <- subset(utility, Month == 7)
ggplot(junes, aes(x=newDate, y=E_kWh_per_Day)) + geom_point(color="blue") + geom_line() + coord_cartesian(ylim = c(0,60))
# Out:
# plot without title

# %%
ggplot(junes, aes(x=newDate, y=E_kWh_per_Day)) + geom_point(color="blue") + geom_line() + coord_cartesian(ylim = c(0,80)) + geom_line(aes(y=Temp_F))

# %%
ggplot(utility, aes(x=newDate, y=Water_Gals_per_Day)) + geom_point(color="green") + geom_line()
# Out:
# plot without title

# %%
library(lubridate)

# %% [markdown]
# # As we can see in the plot above the water usage increases dramatically too 400 gallons per day which is where I believe the serious gardening started.

# %% [markdown]
# # additionally, I think we can also see a lower level of water usage starting between years 2005-2010. This is probably where the household started doing composting to decrease water usage considerably.

# %%
ggplot(utility, aes(x=newDate, y=E_kWh_per_Day)) + geom_point(color="green") + geom_line()
# Out:
# plot without title

# %% [markdown]
# # This is an interesting plot. We can see a lot here. First, over time the electric usage decreases
# most likely due to replacing old bulbs and new technology. Then a little after 2010 there is a dramatic
# decrease which coincides with the gas decrease so this is where the new furnace must have come in. A little
# before 2020 we see a sudden increase, due to first electric car purchase followed by a HUGE decline which
# must be the solar panel installation. Another bump in usafe after 2020 must be the purchase of the second electric car.

# %%
utility$newDate <- ymd(paste(utility$Year, utility$Month, "01", sep="-"))

# %%
ggplot(utility, aes(x=newDate, y=Temp_F)) + geom_point(color="blue") + geom_line()

# %%
options(repr.plot.width=20, repr.plot.height=4)

# %%
ggplot(utility, aes(x=newDate, y=Gas_Th_per_Day)) + geom_point(color="blue") + geom_line()

# %%
utility
